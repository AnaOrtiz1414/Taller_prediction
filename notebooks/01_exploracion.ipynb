# %% [markdown]
# Exploración de la Data:
#
# Iniciamos con la importación de las librerias necesarias para posteriormente realizar la Red Neuronal Backpropagation que vamos a simular. Adicional, del cargue de la data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

import os
os.chdir("C:/Users/ANA/Documents/Maestria/Clase Deeplearning/Taller entregable/Taller_prediction")



from src.data_loader import load_data

# Se cargan los datos. 

dataset_path = r"C:\Users\ANA\Documents\Maestria\Clase Deeplearning\Taller entregable\archive\House_Rent_Dataset.csv"
X_train, X_test, y_train, y_test = load_data(dataset_path)

df_train = pd.DataFrame(X_train)
df_train['target'] = y_train  # Agregar la variable objetivo

df_test = pd.DataFrame(X_test)
df_test['target'] = y_test  # Agregar la variable objetivo
# Out:
# Columnas disponibles en el dataset: ['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type', 'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred', 'Bathroom', 'Point of Contact']

# %% [markdown]
# La exploración de los datos es importante para saber cómo se comportan los datos y a su vez, cómo podemos analizarlos de acuerdo a esto.

# %%
print("Información del dataset:")
print(df_train.info())

print("\nDescripción estadística:")
print(df_train.describe())
# Out:
# Información del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3796 entries, 0 to 3795
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3796 non-null   float64
#  1   1       3796 non-null   float64
#  2   2       3796 non-null   float64
#  3   target  3796 non-null   float64
# dtypes: float64(4)
# memory usage: 118.8 KB
# None
#
# Descripción estadística:
#                   0             1             2        target
# count  3.796000e+03  3.796000e+03  3.796000e+03  3.796000e+03
# mean   4.445572e-17 -8.540177e-17  2.339775e-17  5.615459e-18
# std    1.000132e+00  1.000132e+00  1.000132e+00  1.000132e+00
# min   -1.507092e+00 -1.300098e+00 -1.092556e+00 -4.170229e-01
# 25%   -6.567803e-01 -1.077395e-01 -1.092556e+00 -3.089334e-01
# 50%   -1.843848e-01 -1.077395e-01  3.566558e-02 -2.352361e-01
# 75%    3.667432e-01  1.084619e+00  3.566558e-02 -1.875004e-02
# ...

# %% [markdown]
# A continuación se muestra un gráfico de cómo se distrubuye nuestra variable objetivo. "Precio alquiler"

# %%
# Gráfico de distribución de la variable objetivo
plt.figure(figsize=(8, 5))
sns.histplot(df_train['target'], kde=True, bins=30)
plt.title("Distribución de la variable objetivo")
plt.xlabel("Precio de alquiler")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# Aquí observamos cómo se correlacionan los datos.

# %%
# Gráfico de correlaciones
plt.figure(figsize=(10, 6))
sns.heatmap(df_train.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlación")
plt.show()

print(df_train.corr().columns)
print(df_train.corr().columns)
# Out:
# Index([0, 1, 2, 'target'], dtype='object')
# Index([0, 1, 2, 'target'], dtype='object')

# %% [markdown]
# Por último debemos identificar los valores nulos dentro del dataset.

# %%
# Identificación de valores nulos
print("\nValores nulos por columna:")
print(df_train.isnull().sum())
# Out:
# Valores nulos por columna:
# 0         0
# 1         0
# 2         0
# target    0
# dtype: int64
